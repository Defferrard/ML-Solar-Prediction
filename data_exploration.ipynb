# %% [markdown]
# [Kaggle Dataset](https://www.kaggle.com/competitions/solar-prediction-mini-projet/data)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("training.csv")
df = df.drop(['Unnamed: 0'], axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17856 entries, 0 to 17855
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              17856 non-null  object
#  1   temp              17264 non-null  float64
#  2   humidity          17264 non-null  float64
#  3   precip            17264 non-null  float64
#  4   snow              17264 non-null  float64
#  5   snowdepth         17264 non-null  float64
#  6   windspeed         17264 non-null  float64
#  7   winddir           17264 non-null  float64
#  8   visibility        9588 non-null   float64
#  9   cloudcover        17264 non-null  float64
#  10  solarradiation    9468 non-null   float64
#  11  solarenergy       9336 non-null   float64
#  12  uvindex           9468 non-null   float64
#  13  conditions        17264 non-null  object
#  14  solar_production  17856 non-null  float64
# dtypes: float64(13), object(2)
# memory usage: 2.0+ MB

# %%
df.hist(figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'temp'}>,
#         <AxesSubplot:title={'center':'humidity'}>,
#         <AxesSubplot:title={'center':'precip'}>,
#         <AxesSubplot:title={'center':'snow'}>],
#        [<AxesSubplot:title={'center':'snowdepth'}>,
#         <AxesSubplot:title={'center':'windspeed'}>,
#         <AxesSubplot:title={'center':'winddir'}>,
#         <AxesSubplot:title={'center':'visibility'}>],
#        [<AxesSubplot:title={'center':'cloudcover'}>,
#         <AxesSubplot:title={'center':'solarradiation'}>,
#         <AxesSubplot:title={'center':'solarenergy'}>,
#         <AxesSubplot:title={'center':'uvindex'}>],
#        [<AxesSubplot:title={'center':'solar_production'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
analyses = []
head = np.concatenate((df.keys()[1:13],df.keys()[14:15]))
fig, axs = plt.subplots(len(head), figsize=(20, 150))
i = 0
for key in head:
    col = df[key]
    analyse = {"key": key, "min": col.min(), "max": col.max(), "mean": col.mean(), "var": col.var()}
    analyses.append(analyse)
    axs[i].set_title(key)
    axs[i].plot(df[key])
    i+=1
analyses = pd.DataFrame(analyses)
analyses
# Out:
#                  key        min          max        mean           var
# 0               temp   4.944444    32.055556   17.589383     22.327257
# 1           humidity  25.830000    97.010000   67.190304    276.152475
# 2             precip   0.000000     0.370000    0.006200      0.000525
# 3               snow   0.000000     0.000000    0.000000      0.000000
# 4          snowdepth   0.000000     0.000000    0.000000      0.000000
# 5          windspeed   0.000000    18.300000    5.193119      9.037420
# 6            winddir   0.000000   360.000000  184.106881  15473.226004
# 7         visibility   1.200000    34.200000    8.790363     32.270494
# 8         cloudcover   0.000000   100.000000   27.955955   1323.939616
# 9     solarradiation   0.000000  1076.000000  312.998733  86257.864581
# 10       solarenergy   0.000000     3.900000    1.144087      1.116029
# 11           uvindex   0.000000    10.000000    3.081115      8.906909
# ...

# %%
df["conditions"].unique()
# Out:
# array(['Clear', 'Partially cloudy', 'Rain, Partially cloudy', 'Rain', nan,
#        'Overcast', 'Rain, Overcast'], dtype=object)

# %%
for condition in df["conditions"].unique():
    df.where(df["conditions"] == condition).hist(figsize=(20, 10))

# %%
v1 = pd.read_csv('V1_DEFFHERREAUX.csv')
v2 = pd.read_csv('V2_DEFFHERREAUX.csv')
v3 = pd.read_csv('V3_DEFFHERREAUX.csv')
v4 = pd.read_csv('V4_DEFFHERREAUX.csv')
v5 = pd.read_csv('V5_DEFFHERREAUX.csv')

# %%
r2_score(v5, v2)
# Out:
# 0.7618764399271215

# %%
result =  pd.DataFrame({'v1' : v1['predicted'], 'v3' : v3['predicted'], 'v4' : v4['predicted'], 'temp' : temp['predicted']})

result.plot(figsize=(10, 10))
# Out:
# <AxesSubplot: >
